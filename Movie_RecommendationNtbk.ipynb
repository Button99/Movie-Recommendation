# %% [markdown]
# ### Movies Recommendation System IMDB

# %% [markdown]
# Let's import our tools!

# %%
import pandas as pd 
import numpy as np 
import csv

from sklearn.feature_extraction.text import HashingVectorizer, CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

df_movies= pd.read_csv("../input/imdb-extensive-dataset/IMDb movies.csv")

# %%
df_movies.head()
# Out:
#   imdb_title_id                                              title  \
# 0     tt0000574                        The Story of the Kelly Gang
# 1     tt0001892                                     Den sorte drøm
# 2     tt0002101                                          Cleopatra
# 3     tt0002130                                          L'Inferno
# 4     tt0002199  From the Manger to the Cross; or, Jesus of Naz...
#
#                                       original_title  year date_published  \
# 0                        The Story of the Kelly Gang  1906     1906-12-26
# 1                                     Den sorte drøm  1911     1911-08-19
# 2                                          Cleopatra  1912     1912-11-13
# 3                                          L'Inferno  1911     1911-03-06
# 4  From the Manger to the Cross; or, Jesus of Naz...  1912           1913
#
#                        genre  duration           country language  \
# ...

# %%
df_movies.dtypes
# Out:
# imdb_title_id             object
# title                     object
# original_title            object
# year                       int64
# date_published            object
# genre                     object
# duration                   int64
# country                   object
# language                  object
# director                  object
# writer                    object
# production_company        object
# actors                    object
# description               object
# avg_vote                 float64
# votes                      int64
# budget                    object
# usa_gross_income          object
# worlwide_gross_income     object
# metascore                float64
# reviews_from_users       float64
# reviews_from_critics     float64
# dtype: object

# %% [markdown]
# We'll drop some useless cols

# %%
df_movies= df_movies.drop(["title", "duration", "metascore", "worlwide_gross_income", "date_published", "production_company", "budget", "usa_gross_income", "reviews_from_users", "reviews_from_critics"], axis=1)

# %% [markdown]
# We will work with movies >1995

# %%
df_movies= df_movies[df_movies.year > 1980]

# %% [markdown]
# Drop rows with `Nan` cols

# %%
df_movies.dropna()
# Out:
#       imdb_title_id               original_title  year  \
# 4115      tt0035423               Kate & Leopold  2001
# 4425      tt0036606  Another Time, Another Place  1983
# 12699     tt0062181                 Rece do góry  1981
# 13606     tt0064820       The Plot Against Harry  1989
# 13656     tt0064994            Skrivánci na niti  1990
# ...             ...                          ...   ...
# 81266     tt9899880                     Columbus  2018
# 81267     tt9900782                       Kaithi  2019
# 81268     tt9903716                       Jessie  2019
# 81269     tt9905412                        Ottam  2019
# 81270     tt9905462                    Pengalila  2019
#
#                           genre         country          language  \
# 4115   Comedy, Fantasy, Romance             USA   English, French
# 4425                      Drama              UK  English, Italian
# 12699                     Drama          Poland            Polish
# ...

# %% [raw]
# Create a new csv file

# %%
df_movies.to_csv("Mov.csv")

# %%
df_mov=pd.read_csv("Mov.csv")

df_mov.head()
# Out:
#    Unnamed: 0 imdb_title_id               original_title  year  \
# 0        4115     tt0035423               Kate & Leopold  2001
# 1        4425     tt0036606  Another Time, Another Place  1983
# 2       12699     tt0062181                 Rece do góry  1981
# 3       13606     tt0064820       The Plot Against Harry  1989
# 4       13656     tt0064994            Skrivánci na niti  1990
#
#                       genre         country          language  \
# 0  Comedy, Fantasy, Romance             USA   English, French
# 1                     Drama              UK  English, Italian
# 2                     Drama          Poland            Polish
# 3                    Comedy             USA           English
# 4    Comedy, Drama, Romance  Czechoslovakia             Czech
#
#             director                               writer  \
# 0      James Mangold         Steven Rogers, James Mangold
# 1    Michael Radford     Jessie Kesson, John Francis Lane
# ...

# %%
quant= df_mov["votes"].quantile(0.9)

print("Number of votes: " +str(quant))

mean= df_mov["avg_vote"].mean()

print("Average vote: " +str(mean))
# Out:
# Number of votes: 14108.0
# Average vote: 5.77913943264069

# %%
movies= df_movies.copy().loc[df_movies["votes"] >= quant]

movies.shape
# Out:
# (5983, 12)

# %% [markdown]
# ### Time to find Weight rate

# %%
def Wrate(df, m=mean,  q=quant):
    v=df["votes"]
    R= df["avg_vote"]
    
    return (v/(v+q)* R) + (q/(q+v)* m)

# %% [raw]
# Let's see the score of Wrate.

# %%
movies["score"]= movies.apply(Wrate, axis=1)

# %%
movies= movies.sort_values("score", ascending= False)

movies["original_title"].head()
# Out:
# 27628                         The Shawshank Redemption
# 46756                                  The Dark Knight
# 27558                                     Pulp Fiction
# 33198    The Lord of the Rings: The Return of the King
# 26817                                 Schindler's List
# Name: original_title, dtype: object

# %%
def get_recommendations(title, cosine_sim=cosine_sim):
    # Get the index of the movie that matches the title
    idx = indices[title]

    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:11]

    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar movies
    return df_movies['original_title'].iloc[movie_indices]

# %% [markdown]
# We 'll clean the data and make a new column named features with the existing columns of:
#
#    * `writer`
#
#    * `actors`
#
#    * `director`
#
#    * `genre`
#
#    * `description`

# %%
def clean_data(x):
    if isinstance(x, list):
        return [str.lower(i.replace(" ", "")) for i in x]
    
    else: 
        
        if isinstance(x, str):
            return str.lower(x.replace(" ", ""))
        
        else: return ""

# %%
df_movies.dtypes
# Out:
# index               int64
# imdb_title_id      object
# original_title     object
# year                int64
# genre              object
# country            object
# language           object
# director           object
# writer             object
# actors             object
# description        object
# avg_vote          float64
# votes               int64
# features           object
# dtype: object

# %%
features=["actors", "writer", "director", "genre", "description"]

for f in features:
    df_movies[f]= df_movies[f].apply(clean_data)

# %%
def create_col(x):
    return " ".join(x["writer"]) + " " + " ".join(x["actors"]) + " " + x["director"] + " " + " ".join(x["genre"])+ " "+ " ".join(x["description"])


df_movies["features"] = df_movies.apply(create_col, axis=1)

# %%
cv = CountVectorizer(stop_words="english")
cv_matrix = cv.fit_transform(df_movies["features"])

# %%
cosine_sim = cosine_similarity(cv_matrix, cv_matrix)

# %%
df_movies = df_movies.reset_index()
indices = pd.Series(df_movies.index, index=df_movies["original_title"])

# %%
get_recom("Messo comunale praticamente spione", cosine_sim)
# Out:
# 14906                  Memento
# 17676                 Insomnia
# 21449            Batman Begins
# 25453          The Dark Knight
# 26111             The Prestige
# 27608             Interstellar
# 33679    The Dark Knight Rises
# 33914                Inception
# 52247                  Dunkirk
# 0               Kate & Leopold
# Name: original_title, dtype: object
